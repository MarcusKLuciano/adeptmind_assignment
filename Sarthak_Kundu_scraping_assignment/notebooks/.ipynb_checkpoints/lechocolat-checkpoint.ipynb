# %%
import requests,json
import pandas as pd
from bs4 import BeautifulSoup as bs
from tqdm import tqdm
import re

# %%
def get_all_categories():
    resp = requests.get('https://www.lechocolat-alainducasse.com/uk/')
    cookies = resp.cookies.get_dict()

    headers = {
        'authority': 'www.lechocolat-alainducasse.com',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'en-US,en;q=0.9,en-IN;q=0.8',
        'cache-control': 'no-cache',
        'dnt': '1',
        'pragma': 'no-cache',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
    }

    response = requests.get('https://www.lechocolat-alainducasse.com/uk/', cookies=cookies, headers=headers)
    soup = bs(response.content,'lxml')
    categories = list(set([x['href'] for x in soup.find_all('a',{'class':'siteMenuItem__link'})][:-1]))
    return categories

# %%
def get_products(collection_link):
    resp = requests.get('https://www.lechocolat-alainducasse.com/uk/')
    cookies = resp.cookies.get_dict()
    headers = {
        'authority': 'www.lechocolat-alainducasse.com',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'en-US,en;q=0.9,en-IN;q=0.8',
        'cache-control': 'no-cache',
        'dnt': '1',
        'pragma': 'no-cache',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
    }

    response = requests.get(collection_link, cookies=cookies, headers=headers)
    soup = bs(response.content,'lxml')
    product_links = [x['href'] for x in soup.find('section',{'class':'products__list'}).find_all('a',{'class':'productMiniature__name'})]
    return product_links

# %%
def get_product_details(product_link):
    resp = requests.get('https://www.lechocolat-alainducasse.com/uk/')
    cookies = resp.cookies.get_dict()
    headers = {
        'authority': 'www.lechocolat-alainducasse.com',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'en-US,en;q=0.9,en-IN;q=0.8',
        'cache-control': 'no-cache',
        'dnt': '1',
        'pragma': 'no-cache',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
    }

    response = requests.get(
        product_link,
        cookies=cookies,
        headers=headers,
    )
    soup = bs(response.content,'lxml')
    for x in soup.find_all('script',{'type':'application/ld+json'}):
        if json.loads(x.text)['@type'] == 'Product':
            break
    inter = json.loads(x.text)
    models = get_models_and_prices(soup,inter)
    details = {}
    details["product_id"] =  soup.find('input',{'id':'product_page_product_id'})['value']
    details["title"] = soup.find("meta",{"property":"og:title"})['content']
    details["image"] = inter["image"]
    details["price"] = soup.find("meta",{"property":"product:price:amount"})["content"]
    details["currency"] = soup.find("meta",{"property":"product:price:currency"})["content"]
    try:
        details["description"] = inter["description"].replace('\xa0',' ')
    except:
        details['description'] = soup.find('meta',{'name':'description'})['content']
    details["sales_prices"] = float(soup.find("meta",{"property":"product:pretax_price:amount"})["content"])
    if models == []:
        details['prices'] = [details['sales_prices'],details['price']]
    else:
        details["prices"] = [m['price'] for m in models]
    details["images"] = [x.split(' ')[0] for x in soup.find('img',{'class':'productImages__image'})['srcset'].split(',')]
    details["url"] = inter["url"]
    try:
        if json.loads(soup.find('script',{'class':'product-data-ga4'}).text)["item_brand"] == '':
            details["brand"] = json.loads(soup.find('script',{'class':'product-data-ga4'}).text)["manufacture"]
        else:
            details["brand"] = json.loads(soup.find('script',{'class':'product-data-ga4'}).text)["item_brand"]
    except:
        if json.loads(soup.find('script',{'class':'single-product-data-ga4'}).text)["item_brand"] == '':
            details["brand"] = json.loads(soup.find('script',{'class':'single-product-data-ga4'}).text)["manufacture"]
        else:
            details["brand"] = json.loads(soup.find('script',{'class':'single-product-data-ga4'}).text)["item_brand"]
    if models == []:
        try:
            wt = soup.find('p',{'class':'productCard__weight'}).text
        except:
            wt = ''
        models = [{"id":soup.find('input',{'id':'product_page_product_id'})['value'],"image":inter["image"],"weight":wt,"price":soup.find("meta",{"property":"product:price:amount"})["content"]}]
    details["models"] = models
    return details

# %%
def get_models_and_prices(soup,inter):
    models = []
    resp = requests.get('https://www.lechocolat-alainducasse.com/uk/')
    cookies = resp.cookies.get_dict()
    token = soup.find('input',{'name':'token'})['value']
    product_id = soup.find('input',{'id':'product_page_product_id'})['value']
    soup.find_all('input',{'class':'input-radio'})
    weights = [{'weight':x['title'],'group[6]':x['value']}for x in soup.find_all('input',{'class':'input-radio'})]
    if len(weights) >1:
        for w in weights:
            headers = {
                'authority': 'www.lechocolat-alainducasse.com',
                'accept': 'application/json, text/javascript, */*; q=0.01',
                'accept-language': 'en-US,en;q=0.9,en-IN;q=0.8',
                'cache-control': 'no-cache',
                'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
                'dnt': '1',
                'origin': 'https://www.lechocolat-alainducasse.com',
                'pragma': 'no-cache',
                'referer': 'https://www.lechocolat-alainducasse.com/uk/hazelnut-dragee-dark',
                'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36 Edg/121.0.0.0',
                'x-requested-with': 'XMLHttpRequest',
            }

            params = {
                'controller': 'product',
                'token': token,
                'id_product': product_id,
                'id_customization': '0',
                'group[6]': w['group[6]'],
                'qty': '1',
            }

            data = {
                'quickview': '0',
                'ajax': '1',
                'action': 'refresh',
                'quantity_wanted': '1',
            }

            response = requests.post(
                'https://www.lechocolat-alainducasse.com/uk/index.php',
                params=params,
                cookies=cookies,
                headers=headers,
                data=data,
            )
            if 'Kg' in w['weight']:
                models.append({"id":w['group[6]'],"weight":w["weight"],"image":inter["image"],"price":float(bs(response.json()['product_prices'],'lxml').find('span').text.replace('£',''))})
            else:
                models.append({"id":w['group[6]'],"weight":w["weight"],"image":inter["image"],"price":float(bs(response.json()['product_prices'],'lxml').find('span').text.replace('£',''))})
    return models

# %%
def main():
    product_details = []
    categories = get_all_categories()
    product_links = []
    for c in tqdm(categories,desc='gettign all product links'):
        product_links.extend(get_products(c))
    for p in tqdm(product_links,desc='getting product details'):
        product_details.append(get_product_details(p))
    return product_details

# %%
result = main()
# Out:
# gettign all product links: 100%|██████████████████| 7/7 [00:18<00:00,  2.61s/it]
# getting product details: 100%|████████████████| 137/137 [09:04<00:00,  3.98s/it]

# %%
result
# Out:
# [{'product_id': '944',
#   'title': 'Triumph Bar 75% Dark Chocolate | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/4282-large_default/triumph-bar-dark.jpg',
#   'price': '15',
#   'currency': 'GBP',
#   'description': 'To triumph during this historic sporting event, our Paris Manufacture transforms the Iron Lady into chocolate for victory! To help her cross the finish line, the 75% dark chocolate Triumph Bar is adorned with french hazelnuts and almonds, carefully selected by our chef. Whether as a gift or a treat for yourself, this crunchy, delicious recipe promises an exquisite tasting experience! Taste this ode to French know-how that crowns the efforts of our craftsmen.',
#   'sales_prices': 12.5,
#   'prices': [12.5, '15'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/4282-product_cover_md/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_xs/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_lg/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_xl/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_sm/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_md2x/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_xs2x/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_lg2x/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_xl2x/triumph-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4282-product_cover_sm2x/triumph-bar-dark.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/triumph-bar-dark',
#   'brand': 'Chocolat',
#   'models': [{'id': '944', 'weight': '110g'}]},
#  {'product_id': '73',
#   'title': 'Luxury 6 Chocolate Bars Box  | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3291-large_default/box-bars.jpg',
#   'price': '56',
#   'currency': 'GBP',
#   'description': 'From the grand cru to the single-origin bar, not to mention the Mendiant and the unconched Tradition bar, this set of chocolate bars is an invitation to the sweet world of La Manufacture.6 chocolate bars: 5 dark bars, 1 milk bar',
#   'sales_prices': 46.666667,
#   'prices': [46.666667, '56'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3291-product_cover_md/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_xs/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_lg/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_xl/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_sm/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_md2x/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_xs2x/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_lg2x/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_xl2x/box-bars.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3291-product_cover_sm2x/box-bars.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/box-bars',
#   'brand': 'Chocolat',
#   'models': [{'id': '73', 'weight': '490g'}]},
#  {'product_id': '41',
#   'title': 'Luxury Dark Chocolate Bar Rustic Peru 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3276-large_default/perou-rustic-tradition-chocolate-bar-dark.jpg',
#   'price': '10',
#   'currency': 'GBP',
#   'description': 'A bar of dark chocolate made with beans originating from Peru. Not having undergone the conching stage,  making it closer to that of the bean. The Signature chocolate bars are the combination of a taste with a unique identity, discover recipes revealing the raw and pure character of our selected beans.',
#   'sales_prices': 8.333333,
#   'prices': [8.333333, '10'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3276-product_cover_md/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_xs/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_lg/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_xl/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_sm/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_md2x/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_xs2x/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_lg2x/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_xl2x/perou-rustic-tradition-chocolate-bar-dark.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3276-product_cover_sm2x/perou-rustic-tradition-chocolate-bar-dark.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/perou-rustic-tradition-chocolate-bar-dark',
#   'brand': 'Chocolat',
#   'models': [{'id': '41', 'weight': '75g'}]},
#  {'product_id': '8',
#   'title': 'Luxury Dark Chocolate Bar Extra Dark 100% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3269-large_default/single-origin-bar-dark-peru-100.jpg',
#   'price': '10',
#   'currency': 'GBP',
#   'description': 'A refined and powerful dark chocolate, without added sugar, the pure flavour of cocoa beans originating from Peru, South America. The Signature chocolate bars are the combination of a taste with a unique identity, discover recipes revealing the raw and pure character of our selected beans.',
#   'sales_prices': 8.333333,
#   'prices': [8.333333, '10'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3269-product_cover_md/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_xs/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_lg/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_xl/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_sm/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_md2x/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_xs2x/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_lg2x/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_xl2x/single-origin-bar-dark-peru-100.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3269-product_cover_sm2x/single-origin-bar-dark-peru-100.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/single-origin-bar-dark-peru-100',
#   'brand': 'Chocolat',
#   'models': [{'id': '8', 'weight': '75g'}]},
#  {'product_id': '232',
#   'title': 'Luxury Dark Chocolate Bar The Blend 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3310-large_default/signature-bar-dark-the-blend-75.jpg',
#   'price': '10',
#   'currency': 'GBP',
#   'description': 'The Manufacture invites you to discover its blend, a perfect balance between 4 crus cocoa beans - Peru, Ecuador, Madagascar, Sao Tome - for a unique signature chocolate bar! The Signature chocolate bars are the combination of a taste with a unique identity, discover recipes revealing the raw and pure character of our selected beans.',
#   'sales_prices': 8.333333,
#   'prices': [8.333333, '10'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3310-product_cover_md/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_xs/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_lg/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_xl/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_sm/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_md2x/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_xs2x/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_lg2x/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_xl2x/signature-bar-dark-the-blend-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3310-product_cover_sm2x/signature-bar-dark-the-blend-75.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/signature-bar-dark-the-blend-75',
#   'brand': 'Chocolat',
#   'models': [{'id': '232', 'weight': '75g'}]},
#  {'product_id': '81',
#   'title': 'Luxury Dark Chocolate Bar Sugar Free 85% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3298-large_default/tradition-bar-dark-sugar-free.jpg',
#   'price': '10',
#   'currency': 'GBP',
#   'description': 'To indulge without guilt, La Manufacture offers a sugar-free dark chocolate bar with 85% cocoa  The Signature chocolate bars are the combination of a taste with a unique identity, discover recipes revealing the raw and pure character of our selected beans.',
#   'sales_prices': 8.333333,
#   'prices': [8.333333, '10'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3298-product_cover_md/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_xs/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_lg/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_xl/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_sm/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_md2x/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_xs2x/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_lg2x/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_xl2x/tradition-bar-dark-sugar-free.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3298-product_cover_sm2x/tradition-bar-dark-sugar-free.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/tradition-bar-dark-sugar-free',
#   'brand': 'Chocolat',
#   'models': [{'id': '81', 'weight': '75g'}]},
#  {'product_id': '42',
#   'title': 'Luxury Milk Chocolate Bar Rustic Madagascar 45% | Le Chocolate Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3277-large_default/tradition-bar-madagascar-milk-rustic.jpg',
#   'price': '10',
#   'currency': 'GBP',
#   'description': 'A bar of milk chocolate, with beans originating from Madagascar, Indian Ocean. Not having undergone the conching stage,making it closer to that of the bean. The Signature chocolate bars are the combination of a taste with a unique identity, discover recipes revealing the raw and pure character of our selected beans.',
#   'sales_prices': 8.333333,
#   'prices': [8.333333, '10'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3277-product_cover_md/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_xs/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_lg/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_xl/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_sm/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_md2x/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_xs2x/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_lg2x/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_xl2x/tradition-bar-madagascar-milk-rustic.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3277-product_cover_sm2x/tradition-bar-madagascar-milk-rustic.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/tradition-bar-madagascar-milk-rustic',
#   'brand': 'Chocolat',
#   'models': [{'id': '42', 'weight': '75g'}]},
#  {'product_id': '325',
#   'title': 'Luxury Milk Chocolate Bar Coconut Milk 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3323-large_default/vegan-chocolate-bar-coconut-milk-45.jpg',
#   'price': '9',
#   'currency': 'GBP',
#   'description': 'Discover this brand-new recipe of La Manufacture, 100% vegan and made with coconut milk &amp;amp; Cameroon cocoa beans, a sweet delight!',
#   'sales_prices': 7.5,
#   'prices': [7.5, '9'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3323-product_cover_md/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_xs/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_lg/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_xl/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_sm/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_md2x/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_xs2x/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_lg2x/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_xl2x/vegan-chocolate-bar-coconut-milk-45.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3323-product_cover_sm2x/vegan-chocolate-bar-coconut-milk-45.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/vegan-chocolate-bar-coconut-milk-45',
#   'brand': 'Chocolat',
#   'models': [{'id': '325', 'weight': '75g'}]},
#  {'product_id': '945',
#   'title': 'Triumph Bar 45% Milk Chocolate | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/4284-large_default/triumph-bar-milk.jpg',
#   'price': '15',
#   'currency': 'GBP',
#   'description': 'To triumph during this historic sporting event, our Paris Manufacture transforms the Iron Lady into chocolate for victory! To help her cross the finish line, the 45% milk chocolate Triumph Bar is adorned with french hazelnuts and almonds, carefully selected by our chef. Whether as a gift or a treat for yourself, this crunchy, delicious recipe promises an exquisite tasting experience! Taste this ode to French know-how that crowns the efforts of our craftsmen.',
#   'sales_prices': 12.5,
#   'prices': [12.5, '15'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/4284-product_cover_md/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_xs/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_lg/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_xl/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_sm/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_md2x/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_xs2x/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_lg2x/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_xl2x/triumph-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4284-product_cover_sm2x/triumph-bar-milk.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/triumph-bar-milk',
#   'brand': 'Chocolat',
#   'models': [{'id': '945', 'weight': '110g'}]},
#  {'product_id': '46',
#   'title': 'Luxury Dark Chocolate Mendiant Bar Chopped Pistachios 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3401-large_default/mendiant-bar-dark-chopped-pistachio.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered with chopped pistachios The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3401-product_cover_md/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_xs/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_lg/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_xl/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_sm/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_md2x/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_xs2x/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_lg2x/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_xl2x/mendiant-bar-dark-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3401-product_cover_sm2x/mendiant-bar-dark-chopped-pistachio.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-dark-chopped-pistachio',
#   'brand': 'Chocolat',
#   'models': [{'id': '46', 'weight': '100g'}]},
#  {'product_id': '47',
#   'title': 'Luxury Dark Chocolate Mendiant Bar Cramelised Hazelnut 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3403-large_default/mendiant-bar-dark-caramelized-hazelnut.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered in whole, caramelised hazelnuts The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3403-product_cover_md/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_xs/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_lg/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_xl/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_sm/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_md2x/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_xs2x/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_lg2x/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_xl2x/mendiant-bar-dark-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3403-product_cover_sm2x/mendiant-bar-dark-caramelized-hazelnut.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-dark-caramelized-hazelnut',
#   'brand': 'Chocolat',
#   'models': [{'id': '47', 'weight': '100g'}]},
#  {'product_id': '48',
#   'title': 'Luxury Dark Chocolate Mendiant Bar Caramelised Almond 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3405-large_default/mendiant-bar-caramelised-almond.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered in whole, caramelised almonds The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3405-product_cover_md/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_xs/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_lg/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_xl/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_sm/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_md2x/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_xs2x/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_lg2x/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_xl2x/mendiant-bar-caramelised-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3405-product_cover_sm2x/mendiant-bar-caramelised-almond.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-caramelised-almond',
#   'brand': 'Chocolat',
#   'models': [{'id': '48', 'weight': '100g'}]},
#  {'product_id': '49',
#   'title': 'Luxury Dark Chocolate Mendiant Bar Almonds & Candied Organges & Figs 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3407-large_default/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered in whole, caramelised almonds, pistachios, pine nuts, morsels of figs and candied orange The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3407-product_cover_md/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_xs/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_lg/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_xl/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_sm/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_md2x/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_xs2x/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_lg2x/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_xl2x/mendiant-bar-dark-almond-candied-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3407-product_cover_sm2x/mendiant-bar-dark-almond-candied-orange-fig.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-dark-almond-candied-orange-fig',
#   'brand': 'Chocolat',
#   'models': [{'id': '49', 'weight': '100g'}]},
#  {'product_id': '50',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Caramelised Almond 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3409-large_default/mendiant-bar-milk-caramelized-almond.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered in whole, caramelised almonds The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3409-product_cover_md/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xs/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_lg/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xl/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_sm/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_md2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xs2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_lg2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xl2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_sm2x/mendiant-bar-milk-caramelized-almond.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-caramelized-almond',
#   'brand': 'Chocolat',
#   'models': [{'id': '50', 'weight': '100g'}]},
#  {'product_id': '51',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Almonds & Candied Organges & Figs 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3411-large_default/mendiant-bar-milk-almond-orange-fig.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A milk chocolate bar covered in whole, caramelised almonds, pistachios, pine nuts, morsels of figs and candied orange The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3411-product_cover_md/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_xs/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_lg/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_xl/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_sm/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_md2x/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_xs2x/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_lg2x/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_xl2x/mendiant-bar-milk-almond-orange-fig.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3411-product_cover_sm2x/mendiant-bar-milk-almond-orange-fig.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-almond-orange-fig',
#   'brand': 'Chocolat',
#   'models': [{'id': '51', 'weight': '100g'}]},
#  {'product_id': '53',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Chopped Pistachios 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3413-large_default/mendiant-bar-milk-chopped-pistachio.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A milk chocolate bar covered in whole, chopped pistachios  The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3413-product_cover_md/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_xs/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_lg/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_xl/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_sm/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_md2x/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_xs2x/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_lg2x/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_xl2x/mendiant-bar-milk-chopped-pistachio.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3413-product_cover_sm2x/mendiant-bar-milk-chopped-pistachio.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-chopped-pistachio',
#   'brand': 'Chocolat',
#   'models': [{'id': '53', 'weight': '100g'}]},
#  {'product_id': '40',
#   'title': 'Luxury Dark Chocolate Mendiant Bar Nougatine & Fleur de sel 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3399-large_default/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A bar of dark chocolate encrusted with almond brittle, and a touch of fleur de sel. The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3399-product_cover_md/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_xs/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_lg/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_xl/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_sm/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_md2x/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_xs2x/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_lg2x/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_xl2x/mendiant-bar-dark-nougatine-fleur-de-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3399-product_cover_sm2x/mendiant-bar-dark-nougatine-fleur-de-sel.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-dark-nougatine-fleur-de-sel',
#   'brand': 'Chocolat',
#   'models': [{'id': '40', 'weight': '100g'}]},
#  {'product_id': '80',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Nougatine & fleur de sel 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3423-large_default/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A bar of milk chocolate dotted with almond brittle and seasoned with a salty note from the hint of fleur de sel The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3423-product_cover_md/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_xs/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_lg/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_xl/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_sm/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_md2x/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_xs2x/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_lg2x/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_xl2x/mendiant-bar-milk-nougatine-fleur-sel.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3423-product_cover_sm2x/mendiant-bar-milk-nougatine-fleur-sel.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-nougatine-fleur-sel',
#   'brand': 'Chocolat',
#   'models': [{'id': '80', 'weight': '100g'}]},
#  {'product_id': '54',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Cramelised Hazelnut 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3415-large_default/mendiant-bar-milk-caramelized-hazelnut.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A milk chocolate bar covered in whole, caramelised hazelnuts The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3415-product_cover_md/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_xs/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_lg/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_xl/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_sm/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_md2x/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_xs2x/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_lg2x/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_xl2x/mendiant-bar-milk-caramelized-hazelnut.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3415-product_cover_sm2x/mendiant-bar-milk-caramelized-hazelnut.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-caramelized-hazelnut',
#   'brand': 'Chocolat',
#   'models': [{'id': '54', 'weight': '100g'}]},
#  {'product_id': '84',
#   'title': 'Luxury Dark Chocolate Bar Ecuador National Arriba 85% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3299-large_default/single-origin-bar-equador-85.jpg',
#   'price': '12',
#   'currency': 'GBP',
#   'description': 'With a 5,000-year-old genetic lineage, Ecuador’s famous heirloom cocoa - Nacional - from the Finca Garyth farm embodies centuries of cocoa tradition. A true single-origin “grand cru”, it is a complex blend of wild tropical flavours, fresh almonds, a vegetal undertone and banana in the finish. The Single-Origin bars explore the original taste of cocoa beans from diverse provenances.',
#   'sales_prices': 10.0,
#   'prices': [10.0, '12'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3299-product_cover_md/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_xs/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_lg/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_xl/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_sm/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_md2x/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_xs2x/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_lg2x/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_xl2x/single-origin-bar-equador-85.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3299-product_cover_sm2x/single-origin-bar-equador-85.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/single-origin-bar-equador-85',
#   'brand': 'Chocolat',
#   'models': [{'id': '84', 'weight': '75g'}]},
#  {'product_id': '624',
#   'title': 'Dark Chocolate Bar Madagascar Mivoatra 85% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3398-large_default/madagascar-mivoatra-bar.jpg',
#   'price': '12',
#   'currency': 'GBP',
#   'description': 'Cru d&#039;Exception among our range of chocolate bars, this chocolate from Madagascar presents strong and musky flavours. Raw and acidulous notes emerge during tasting. From the cocoa bean to the chocolate bar, including roasting and conching, all the production stages are carried out in our factory. With a range of different origins, our Cru d&#039;Exception chocolate bars explore the original taste of cocoa beans.',
#   'sales_prices': 10.0,
#   'prices': [10.0, '12'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3398-product_cover_md/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_xs/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_lg/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_xl/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_sm/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_md2x/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_xs2x/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_lg2x/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_xl2x/madagascar-mivoatra-bar.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3398-product_cover_sm2x/madagascar-mivoatra-bar.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/madagascar-mivoatra-bar',
#   'brand': 'Chocolat',
#   'models': [{'id': '624', 'weight': '75g'}]},
#  {'product_id': '607',
#   'title': 'Dark Chocolate Bar Tanzania 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3390-large_default/tanzanie.jpg',
#   'price': '9',
#   'currency': 'GBP',
#   'description': 'Cru d&#039;Exception among our range of chocolate bars, this chocolate from Tanzania presents bright and fruity notes. Notes of citrus, acidulous and fresh, emerge during tasting. From the cocoa bean to the chocolate bar, including roasting and conching, all the production stages are carried out in our factory. With a range of different origins, our Cru d&#039;Exception chocolate bars explore the original taste of cocoa beans.',
#   'sales_prices': 7.5,
#   'prices': [7.5, '9'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3390-product_cover_md/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_xs/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_lg/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_xl/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_sm/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_md2x/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_xs2x/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_lg2x/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_xl2x/tanzanie.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3390-product_cover_sm2x/tanzanie.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/tanzanie',
#   'brand': 'Chocolat',
#   'models': [{'id': '607', 'weight': '75g'}]},
#  {'product_id': '61',
#   'title': 'Luxury Dark Chocolate Bar Vietnam 75% | Le Chocolate Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3278-large_default/single-origin-bar-dark-vietnam-75.jpg',
#   'price': '9',
#   'currency': 'GBP',
#   'description': 'A rugged and slightly acidic dark chocolate, made with beans originating from Vietnam, Asia The Single-Origin bars explore the purity and diversity of various sources. With a range of different origins and as many refined flavours, our bars reveal the personality of their producing country and terroir.',
#   'sales_prices': 7.5,
#   'prices': [7.5, '9'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3278-product_cover_md/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_xs/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_lg/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_xl/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_sm/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_md2x/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_xs2x/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_lg2x/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_xl2x/single-origin-bar-dark-vietnam-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3278-product_cover_sm2x/single-origin-bar-dark-vietnam-75.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/single-origin-bar-dark-vietnam-75',
#   'brand': 'Chocolat',
#   'models': [{'id': '61', 'weight': '75g'}]},
#  {'product_id': '319',
#   'title': 'Luxury Dark Chocolate Bar Philippines Trinitario 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3322-large_default/single-origin-bar-dark-philippines-trinitario-75.jpg',
#   'price': '12',
#   'currency': 'GBP',
#   'description': 'Grown in the tropical region of Davao, at Paquibato in Southeastern Philippines, this cocoa is a balanced blend of fruity and sour notes. A true single-origin &quot;grand cru&quot;, it gathers the flavors of tropical fruits, berries, citrus and of roasted nuts. The Single-Origin bars explore the original taste of cocoa beans from diverse provenances.',
#   'sales_prices': 10.0,
#   'prices': [10.0, '12'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3322-product_cover_md/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_xs/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_lg/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_xl/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_sm/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_md2x/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_xs2x/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_lg2x/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_xl2x/single-origin-bar-dark-philippines-trinitario-75.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3322-product_cover_sm2x/single-origin-bar-dark-philippines-trinitario-75.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/single-origin-bar-dark-philippines-trinitario-75',
#   'brand': 'Chocolat',
#   'models': [{'id': '319', 'weight': '75g'}]},
#  {'product_id': '233',
#   'title': 'Luxury Dark Chocolate Bar Peru Chuncho 75% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3311-large_default/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#   'price': '12',
#   'currency': 'GBP',
#   'description': 'The Single-Origin bars explore the purity and diversity of various sources. With a range of different origins and as many refined flavours, our bars reveal the personality of their producing country and terroir.',
#   'sales_prices': 10.0,
#   'prices': [10.0, '12'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3311-product_cover_md/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_xs/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_lg/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_xl/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_sm/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_md2x/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_xs2x/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_lg2x/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_xl2x/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3311-product_cover_sm2x/single-origin-bar-dark-chuncho-peru-75-grand-cru.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/single-origin-bar-dark-chuncho-peru-75-grand-cru',
# ...
#   'sales_prices': 26.666667,
#   'prices': [26.666667, '32'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3334-product_cover_md/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_xs/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_lg/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_xl/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_sm/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_md2x/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_xs2x/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_lg2x/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_xl2x/discovery-box-21-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3334-product_cover_sm2x/discovery-box-21-pieces.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/discovery-box-21-pieces',
#   'brand': 'Chocolat',
#   'models': [{'id': '11', 'weight': '170g'}]},
#  {'product_id': '50',
#   'title': 'Luxury Milk Chocolate Mendiant Bar Caramelised Almond 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3409-large_default/mendiant-bar-milk-caramelized-almond.jpg',
#   'price': '13',
#   'currency': 'GBP',
#   'description': 'A dark chocolate bar with 75% cocoa covered in whole, caramelised almonds The Mendiant chocolate bar hark back to the classic recipe of the same name, containing dried fruit... or not! Crunchy bars of chocolate covered with luscious ingredients, candied fruits, caramelised hazelnuts or chopped pistachios.',
#   'sales_prices': 10.833333,
#   'prices': [10.833333, '13'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3409-product_cover_md/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xs/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_lg/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xl/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_sm/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_md2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xs2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_lg2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_xl2x/mendiant-bar-milk-caramelized-almond.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3409-product_cover_sm2x/mendiant-bar-milk-caramelized-almond.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/mendiant-bar-milk-caramelized-almond',
#   'brand': 'Chocolat',
#   'models': [{'id': '50', 'weight': '100g'}]},
#  {'product_id': '116',
#   'title': 'Luxury Milk Chocolate Bar 45% | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3302-large_default/chocolate-single-bar-milk.jpg',
#   'price': '25',
#   'currency': 'GBP',
#   'description': 'In dark chocolate praline or milk chocolate. Individual bars of chocolate to enjoy on the go or slipped into a piece of bread. This compact and practical box is easily transportable, for an impromptu snack, a picnic, at the office, traveling... 20 individually wrapped bars - 240 g',
#   'sales_prices': 20.833333,
#   'prices': [20.833333, '25'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3302-product_cover_md/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_xs/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_lg/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_xl/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_sm/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_md2x/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_xs2x/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_lg2x/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_xl2x/chocolate-single-bar-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3302-product_cover_sm2x/chocolate-single-bar-milk.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/chocolate-single-bar-milk',
#   'brand': 'Chocolat',
#   'models': [{'id': '116', 'weight': '240g'}]},
#  {'product_id': '102',
#   'title': 'Luxury Hazerlnut Chocolate Spread XL | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3301-large_default/chocolate-spread-xl.jpg',
#   'price': '40',
#   'currency': 'GBP',
#   'description': 'Deliciously regressive, spreadable chocolate...Created from an almond and hazelnut praline, dark chocolate and milk chocolate, this spread will put a smile on the faces of children and grown-ups alike. Similarly to the Manufacture’s old-fashioned pralines, the spread has a slightly granulose texture making it unique and ultra- delicious.XL size 550g',
#   'sales_prices': 33.333333,
#   'prices': [33.333333, '40'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3301-product_cover_md/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_xs/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_lg/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_xl/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_sm/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_md2x/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_xs2x/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_lg2x/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_xl2x/chocolate-spread-xl.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3301-product_cover_sm2x/chocolate-spread-xl.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/chocolate-spread-xl',
#   'brand': 'Chocolat',
#   'models': [{'id': '102', 'weight': '550g'}]},
#  {'product_id': '947',
#   'title': 'Praliné Triumph Hexagone 45% Milk Chocolate | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/4281-large_default/triumph-hexagone-milk.jpg',
#   'price': '15',
#   'currency': 'GBP',
#   'description': 'With its medal-like shape, the Praliné Triumph Hexagon transports you to this french based sporting event. Containing a treasure trove of French pistachio and almond praliné, it invites you to take part in this very special moment. If you want to reach the end and win the chocolate laurels, dare to enjoy it! Whether as a gift or for yourself, this 45% Milk Chocolate creation from our Manufacture promises a tasting experience full of flavor.',
#   'sales_prices': 12.5,
#   'prices': [12.5, '15'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/4281-product_cover_md/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_xs/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_lg/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_xl/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_sm/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_md2x/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_xs2x/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_lg2x/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_xl2x/triumph-hexagone-milk.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4281-product_cover_sm2x/triumph-hexagone-milk.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/triumph-hexagone-milk',
#   'brand': 'Chocolat',
#   'models': [{'id': '947', 'weight': '70g'}]},
#  {'product_id': '471',
#   'title': 'Coffret cadeau découverte',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/2666-large_default/coffret-cadeau-decouverte.jpg',
#   'price': '0',
#   'currency': 'GBP',
#   'description': '',
#   'sales_prices': 0.0,
#   'prices': [0.0, '0'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/2653-product_cover_md/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_xs/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_lg/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_xl/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_sm/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_md2x/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_xs2x/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_lg2x/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_xl2x/coffret-cadeau-decouverte.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/2653-product_cover_sm2x/coffret-cadeau-decouverte.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/coffret-cadeau-decouverte',
#   'brand': 'Chocolat',
#   'models': [{'id': '471', 'weight': '210g'}]},
#  {'product_id': '365',
#   'title': 'Pépites Box 36 pieces of luxury French chocolate | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/4289-large_default/pepites-box-36-pieces.jpg',
#   'price': '57',
#   'currency': 'GBP',
#   'description': 'This box contains 36 Pépites - small chocolate bites - exploring 6 flavors. In addition to the unmissable Caramel Hazelnut ones, the Manufacture offers you to discover new recipes.These Chocolates are best eaten within 6 weeks of purchase',
#   'sales_prices': 47.5,
#   'prices': [47.5, '57'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/4289-product_cover_md/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_xs/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_lg/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_xl/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_sm/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_md2x/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_xs2x/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_lg2x/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_xl2x/pepites-box-36-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/4289-product_cover_sm2x/pepites-box-36-pieces.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/pepites-box-36-pieces',
#   'brand': 'Chocolat',
#   'models': [{'id': '365', 'weight': '337g'}]},
#  {'product_id': '611',
#   'title': 'Dark Chocolate Filled Bar Coco Pralinée 75% | le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3481-large_default/filled-bar-dark-coconut-praline.jpg',
#   'price': '15',
#   'currency': 'GBP',
#   'description': 'The coconut praliné from the Manufacture is entering the range of filled bars for the happiness of the most gourmands! This 75% Signature Blend dark chocolate bar is filled with two preparations made by our chocolate craftsmen. First a praliné with roasted coconut and almonds, then a caramel, also with coconut. The crunchiness of the praliné and the smoothness of the caramel combined to the crisp of the chocolate layers create a delicious game of textures, for a great moment of indulgence.',
#   'sales_prices': 12.5,
#   'prices': [12.5, '15'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3481-product_cover_md/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_xs/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_lg/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_xl/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_sm/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_md2x/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_xs2x/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_lg2x/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_xl2x/filled-bar-dark-coconut-praline.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3481-product_cover_sm2x/filled-bar-dark-coconut-praline.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/filled-bar-dark-coconut-praline',
#   'brand': 'Chocolat',
#   'models': [{'id': '611', 'weight': '110g'}]},
#  {'product_id': '318',
#   'title': 'Pépites box Milk Chocolate Praliné of luxury French chocolate | Le Chocolat Alain Ducasse',
#   'image': 'https://www.lechocolat-alainducasse.com/uk/3321-large_default/pepites-box-milk-16-pieces.jpg',
#   'price': '27',
#   'currency': 'GBP',
#   'description': 'This box contains 16 luscious &quot;pépites&quot; - small milk chocolate bites. Inside each of them : our famous &quot;old-style&quot; hazelnut praliné, a small dose of caramel and crunchy crushed hazelnuts. A treasure for praline lovers ! Our Chocolates are best eaten within 5 weeks of purchase',
#   'sales_prices': 22.5,
#   'prices': [22.5, '27'],
#   'iamges': ['https://www.lechocolat-alainducasse.com/uk/3321-product_cover_md/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_xs/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_lg/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_xl/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_sm/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_md2x/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_xs2x/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_lg2x/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_xl2x/pepites-box-milk-16-pieces.jpg',
#    'https://www.lechocolat-alainducasse.com/uk/3321-product_cover_sm2x/pepites-box-milk-16-pieces.jpg'],
#   'url': 'https://www.lechocolat-alainducasse.com/uk/pepites-box-milk-16-pieces',
#   'brand': 'Chocolat',
#   'models': [{'id': '318', 'weight': '150g'}]}]

# %%
with open('../output/le_chocolat.json','w') as f:
    json.dump(result,f)
